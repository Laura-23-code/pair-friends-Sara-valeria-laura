# %%
import pandas as pd 
#Datos de los 20 países más vistos y sus temporadas/años 
data = { 'Pais': [ 'Estados Unidos', 'India', 'Reino Unido', 'China', 'Brasil', 'Canadá', 'Alemania', 'Francia', 'México', 'Australia', 'España', 'Turquía', 'Italia', 'Japón', 'Argentina', 'Egipto', 'Filipinas', 'Polonia', 'Corea del Sur', 'Países Bajos' ], 
        'Visualizaciones_M': [ 52.5, 38.2, 25.1, 22.8, 18.4, 15.2, 14.8, 13.5, 12.1, 10.4, 9.8, 8.5, 8.2, 7.9, 7.2, 6.8, 6.5, 5.9, 5.4, 5.1 ],
         # Años de emisión originales (Serie completa 1994-2004)
          'Inicio_Emision': [1994] * 20, 'Fin_Emision': [2004] * 20, 'Temporadas_Totales': [10] * 20 }
df_friends_top20 = pd.DataFrame(data) 
# Guardamos para que Power BI lo lea perfecto 
df_friends_top20.to_csv('Friends_Top20_Paises_Anos.csv', index=False, encoding='utf-8-sig') 
print("Archivo 'Friends_Top20_Paises_Anos.csv' creado con éxito.")
# Out:
# Archivo 'Friends_Top20_Paises_Anos.csv' creado con éxito.

# %%
print(df_friends_top20)
# Out:
#               Pais  Visualizaciones_M  Inicio_Emision  Fin_Emision  \
# 0   Estados Unidos               52.5            1994         2004
# 1            India               38.2            1994         2004
# 2      Reino Unido               25.1            1994         2004
# 3            China               22.8            1994         2004
# 4           Brasil               18.4            1994         2004
# 5           Canadá               15.2            1994         2004
# 6         Alemania               14.8            1994         2004
# 7          Francia               13.5            1994         2004
# 8           México               12.1            1994         2004
# 9        Australia               10.4            1994         2004
# 10          España                9.8            1994         2004
# 11         Turquía                8.5            1994         2004
# 12          Italia                8.2            1994         2004
# ...
